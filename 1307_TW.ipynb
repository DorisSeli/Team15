# %% [markdown]
# <a href="https://colab.research.google.com/github/DorisSeli/Team15/blob/main/1307_TW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To complete the tasks use 'transaction_dataset.csv'
#
# Task 1: Create a bar chart that shows the count of transactions for each unique value in the 'Gender' column (including NaN values). - easy

# %%
#TASK 1

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/transaction_dataset.csv')

count_gender = df['Gender'].value_counts(dropna=False)
count_gender.plot(kind='bar')
plt.title('Count customers by gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Task 2: Create a horizontal bar chart that shows the top 5 most frequent names in the DataFrame, based on the 'name' column. (First, create a grouped DataFrame (name_df), then filter it using iloc, and finally create the visualization.) -medium

# %%
#TASK 2

import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv('/content/transaction_dataset.csv')
name_df = df1.iloc[:, 1].value_counts()
name_df.head().plot(kind='barh')
plt.title('Top 5 most frequent names')
plt.xlabel('Count')
plt.ylabel('Name')
plt.show()

# %% [markdown]
# Task 3: Create a filtered DataFrame that includes Category == 'Clothing' and Gender == 'M'. How many rows are there in this filtered DataFrame? Format the result as follows: The filtered DataFrame has XXXX rows. - hard

# %%
#TASK 3

import pandas as pd
import matplotlib.pyplot as plt

df2 = pd.read_csv('/content/transaction_dataset.csv')

filtered_df = df2[(df2['Category']=='Clothing') & (df2['Gender'] =='M')]
print(f'The filtered DataFrame has {filtered_df.shape[0]} rows')
# Out:
# The filtered DataFrame has 3738 rows
